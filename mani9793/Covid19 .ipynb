# %%
# !pip install COVID19Py
# Out:
# ...
#   Created wheel for COVID19Py: filename=COVID19Py-0.3.0-cp37-none-any.whl size=4742 sha256=ba1f34e7abf2f44cbbc7d24d7f11bdf71e30f0725690d3c8f0aa19c2a04cfe5e
#   Stored in directory: C:\Users\talk2\AppData\Local\pip\Cache\wheels\23\78\50\78aaca989f422d636b01b9c55cd5e327fef838e973690f886c
# Successfully built COVID19Py
# ...

# %%
#IMPORTING LIBRARY

import COVID19Py
import matplotlib.pyplot as plt
#creating instance
#covid19 = COVID19Py.COVID19()
#generating data

name=input("enter country name:")
#virusdata=covid19.get_status_by_country_name(name)
data = covid19.getAll()
print(data)
#active
active = data['active']
recover = data['recovered']
deaths = data['deaths']
#plotting pie graph 
plt.pie([active,recover,deaths],labels=['active','recoverd','deaths'],colors=['b','g','r'],explode=(0,0,0.2),startangle=180,autopct='%1.1f%%',shadow=True)
#display the plot
plt.title(name)
plt.legend()
plt.show()
# Out:
# enter country name:india
# ...
