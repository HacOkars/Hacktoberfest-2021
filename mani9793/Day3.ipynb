# %%
def save_user(**user):
    print(user)
    
    
save_user(id=1, name ="admin")
# Out:
# {'id': 1, 'name': 'admin'}

# %%
def greet():
    message ="a"
    
greet()    
print(message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2c6a4df594b7> in <module>
#       3
#       4 greet()
# ----> 5 print(message)
#
# NameError: name 'message' is not defined
