# %%
print("hello jupyter")
# Out:
# hello jupyter

# %%
x,y=1,2
print((x),(y))
print(x,y)
# Out:
# 1 2
# 1 2

# %%
x=1
print(id(x))
# Out:
# 140706529941152

# %%
name="mansi"
print(len(name))
print(name[0])
print(name[-1])
print(name[0:3])
print(name[:3])
print(name[0:])
print(name[:])
# Out:
# 5
# m
# i
# man
# man
# mansi
# mansi

# %%
nums1 = [1,2,3,0,0,0]
nums2 = [2,5,6]
m = len(nums1)
nums3 = nums1+nums2
print(sorted(int(nums3.remove(0))))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a0ab29764cf2> in <module>
#       3 m = len(nums1)
#       4 nums3 = nums1+nums2
# ----> 5 print(sorted(int(nums3.remove(0))))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
